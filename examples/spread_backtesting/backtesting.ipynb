# %%
from vnpy.trader.optimize import OptimizationSetting
from vnpy_spreadtrading.backtesting import BacktestingEngine
from vnpy_spreadtrading.strategies.statistical_arbitrage_strategy import (
    StatisticalArbitrageStrategy
)
from vnpy_spreadtrading.base import LegData, SpreadData
from datetime import datetime

# %%
spread = SpreadData(
    name="IF-Spread",
    legs=[LegData("IF1911.CFFEX"), LegData("IF1912.CFFEX")],
    variable_symbols={"A": "IF1911.CFFEX", "B": "IF1912.CFFEX"},
    variable_directions={"A": 1, "B": -1},
    price_formula="A-B",
    trading_multipliers={"IF1911.CFFEX": 1, "IF1912.CFFEX": 1},
    active_symbol="IF1911.CFFEX",
    min_volume=1,
    compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
)

# %%
engine = BacktestingEngine()
engine.set_parameters(
    spread=spread,
    interval="1m",
    start=datetime(2019, 6, 10),
    end=datetime(2019, 11, 10),
    rate=0,
    slippage=0,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)
engine.add_strategy(StatisticalArbitrageStrategy, {})

# %%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2025-12-02 16:06:32.768888	开始加载历史数据
# 2025-12-02 16:06:32.771890	历史数据加载完成，数据量：0
# 2025-12-02 16:06:32.774890	策略初始化完成
# 2025-12-02 16:06:32.774890	开始回放历史数据
# 2025-12-02 16:06:32.774890	历史数据回放结束
# 2025-12-02 16:06:32.774890	开始计算逐日盯市盈亏
# 2025-12-02 16:06:32.774890	回测成交记录为空
# 2025-12-02 16:06:32.774890	逐日盯市盈亏计算完成
# 2025-12-02 16:06:32.774890	开始计算策略统计指标
# 2025-12-02 16:06:32.774890	------------------------------
# 2025-12-02 16:06:32.774890	首个交易日：
# 2025-12-02 16:06:32.774890	最后交易日：
# 2025-12-02 16:06:32.774890	总交易日：	0
# 2025-12-02 16:06:32.774890	盈利交易日：	0
# 2025-12-02 16:06:32.774890	亏损交易日：	0
# 2025-12-02 16:06:32.774890	起始资金：	1,000,000.00
# 2025-12-02 16:06:32.774890	结束资金：	0.00
# 2025-12-02 16:06:32.774890	总收益率：	0.00%
# 2025-12-02 16:06:32.774890	年化收益：	0.00%
# 2025-12-02 16:06:32.774890	最大回撤: 	0.00
# 2025-12-02 16:06:32.774890	百分比最大回撤: 0.00%
# 2025-12-02 16:06:32.774890	最长回撤天数: 	0
# 2025-12-02 16:06:32.774890	总盈亏：	0.00
# 2025-12-02 16:06:32.774890	总手续费：	0.00
# 2025-12-02 16:06:32.774890	总滑点：	0.00
# 2025-12-02 16:06:32.774890	总成交金额：	0.00
# 2025-12-02 16:06:32.774890	总成交笔数：	0
# 2025-12-02 16:06:32.774890	日均盈亏：	0.00
# 2025-12-02 16:06:32.774890	日均手续费：	0.00
# 2025-12-02 16:06:32.774890	日均滑点：	0.00
# 2025-12-02 16:06:32.774890	日均成交金额：	0.00
# 2025-12-02 16:06:32.774890	日均成交笔数：	0
# 2025-12-02 16:06:32.774890	日均收益率：	0.00%
# 2025-12-02 16:06:32.774890	收益标准差：	0.00%
# 2025-12-02 16:06:32.774890	Sharpe Ratio：	0.00
# 2025-12-02 16:06:32.774890	收益回撤比：	0.00

# %%
for trade in engine.trades.values():
    print(trade)

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("boll_window", 10, 30, 1)
setting.add_parameter("boll_dev", 1, 3, 1)

engine.run_ga_optimization(setting)
# Out:
# 2025-12-02 16:06:33.984199	开始执行遗传算法优化
# 2025-12-02 16:06:33.984199	参数优化空间：63
# 2025-12-02 16:06:33.984199	每代族群总数：100
# 2025-12-02 16:06:33.984199	优良筛选个数：80
# 2025-12-02 16:06:33.984199	迭代次数：30
# 2025-12-02 16:06:33.984199	交叉概率：95%
# 2025-12-02 16:06:33.984199	突变概率：5%
# 2025-12-02 16:06:33.984199	个体突变概率：100%
# gen	nevals
# 0  	100
# 1  	100
# 2  	100
# 3  	100
# 4  	100
# 5  	100
# 6  	100
# 7  	100
# 8  	100
# 9  	100
# 10 	100
# 11 	100
# 12 	100
# 13 	100
# 14 	100
# 15 	100
# 16 	100
# 17 	100
# 18 	100
# 19 	100
# 20 	100
# 21 	100
# 22 	100
# 23 	100
# 24 	100
# 25 	100
# 26 	100
# 27 	100
# 28 	100
# 29 	100
# 30 	100
# 2025-12-02 16:06:40.900129	遗传算法优化完成，耗时6秒
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 10, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 25, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 22, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 23, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 14, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 14, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 24, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 26, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 22, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 19, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.014924	参数：{'boll_window': 28, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 17, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 28, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 19, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 12, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 14, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 18, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 17, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 10, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 27, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 20, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 12, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 13, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 24, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 19, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 17, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 25, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 23, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 13, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 25, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 16, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 22, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 27, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 30, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 20, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 30, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 26, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 23, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 21, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 16, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 29, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 11, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 11, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 15, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 11, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 16, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 10, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 21, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 29, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 28, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 24, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 27, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 18, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 15, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 15, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 12, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 13, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 30, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 26, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 20, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 18, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 21, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:41.015924	参数：{'boll_window': 29, 'boll_dev': 1}, 目标：0
# [({'boll_window': 10, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 25, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 22, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 23, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 14, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 14, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 24, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 26, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 22, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 19, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 28, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 17, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 28, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 19, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 12, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 14, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 18, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 17, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 10, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 27, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 20, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 12, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 13, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 24, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 19, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 17, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 25, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 23, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 13, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 25, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 16, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 22, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 27, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 30, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 20, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 30, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 26, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 23, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 21, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 16, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 29, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 11, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 11, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 15, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 11, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 16, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 10, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 21, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 29, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 28, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 24, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 27, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 18, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 15, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 15, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 12, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 13, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 30, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 26, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 20, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 18, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 21, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 29, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0})]

# %%
engine.run_bf_optimization(setting)
# Out:
# 2025-12-02 16:06:41.064917	开始执行穷举算法优化
# 2025-12-02 16:06:41.064917	参数优化空间：63
# 100%|██████████| 63/63 [00:02<00:00, 23.78it/s]
# 2025-12-02 16:06:45.188297	穷举算法优化完成，耗时4秒
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 10, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 10, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 10, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 11, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 11, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 11, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 12, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 12, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 12, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 13, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 13, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 13, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 14, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 14, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 14, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 15, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 15, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 15, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 16, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 16, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 16, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 17, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 17, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 17, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 18, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 18, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 18, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 19, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 19, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 19, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 20, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 20, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 20, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 21, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 21, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 21, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 22, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 22, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 22, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 23, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 23, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 23, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 24, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 24, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 24, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 25, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 25, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 25, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 26, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 26, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 26, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 27, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 27, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 27, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 28, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 28, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 28, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 29, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 29, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 29, 'boll_dev': 3}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 30, 'boll_dev': 1}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 30, 'boll_dev': 2}, 目标：0
# 2025-12-02 16:06:45.550104	参数：{'boll_window': 30, 'boll_dev': 3}, 目标：0
# [({'boll_window': 10, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 10, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 10, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 11, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 11, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 11, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 12, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 12, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 12, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 13, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 13, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 13, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 14, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 14, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 14, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 15, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 15, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 15, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 16, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 16, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 16, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 17, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 17, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 17, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 18, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 18, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 18, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 19, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 19, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 19, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 20, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 20, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 20, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 21, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 21, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 21, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 22, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 22, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 22, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 23, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 23, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 23, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 24, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 24, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 24, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 25, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 25, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 25, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 26, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 26, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 26, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 27, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 27, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 27, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 28, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 28, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 28, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 29, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 29, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 29, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 30, 'boll_dev': 1},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 30, 'boll_dev': 2},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ({'boll_window': 30, 'boll_dev': 3},
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0})]
