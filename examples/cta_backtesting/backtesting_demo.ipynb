# %%
from datetime import datetime

from vnpy.trader.optimize import OptimizationSetting
from vnpy_ctastrategy.backtesting import BacktestingEngine
from vnpy_ctastrategy.strategies.atr_rsi_strategy import AtrRsiStrategy

# %%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="IF888.CFFEX",
    interval="1m",
    start=datetime(2019, 1, 1),
    end=datetime(2019, 4, 30),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)
engine.add_strategy(AtrRsiStrategy, {})

# %%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2025-12-03 16:06:33.392617	开始加载历史数据
# 2025-12-03 16:06:33.392617	加载进度：# [0%]
# 2025-12-03 16:06:33.424131	加载进度：# [9%]
# 2025-12-03 16:06:33.425131	加载进度：## [18%]
# 2025-12-03 16:06:33.425131	加载进度：### [28%]
# 2025-12-03 16:06:33.426131	加载进度：#### [37%]
# 2025-12-03 16:06:33.426131	加载进度：##### [46%]
# 2025-12-03 16:06:33.427131	加载进度：###### [55%]
# 2025-12-03 16:06:33.428131	加载进度：####### [65%]
# 2025-12-03 16:06:33.428131	加载进度：######## [74%]
# 2025-12-03 16:06:33.429131	加载进度：######### [83%]
# 2025-12-03 16:06:33.430131	加载进度：########## [92%]
# 2025-12-03 16:06:33.430131	历史数据加载完成，数据量：0
# 2025-12-03 16:06:33.431131	策略初始化完成
# 2025-12-03 16:06:33.431131	开始回放历史数据
# 2025-12-03 16:06:33.431131	历史数据回放结束
# 2025-12-03 16:06:33.431131	开始计算逐日盯市盈亏
# 2025-12-03 16:06:33.431131	回测成交记录为空
# 2025-12-03 16:06:33.431131	逐日盯市盈亏计算完成
# 2025-12-03 16:06:33.431131	开始计算策略统计指标
# 2025-12-03 16:06:33.431131	回测结果为空，无法计算绩效统计指标

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_length", 25, 27, 1)
setting.add_parameter("atr_ma_length", 10, 30, 10)

engine.run_ga_optimization(setting)
# Out:
# 2025-12-03 16:06:34.611601	开始执行遗传算法优化
# 2025-12-03 16:06:34.612603	参数优化空间：9
# 2025-12-03 16:06:34.612603	每代族群总数：100
# 2025-12-03 16:06:34.612603	优良筛选个数：80
# 2025-12-03 16:06:34.612603	迭代次数：30
# 2025-12-03 16:06:34.612603	交叉概率：95%
# 2025-12-03 16:06:34.612603	突变概率：5%
# 2025-12-03 16:06:34.612603	个体突变概率：100%
# gen	nevals
# 0  	100
# 1  	100
# 2  	100
# 3  	100
# 4  	100
# 5  	100
# 6  	100
# 7  	100
# 8  	100
# 9  	100
# 10 	100
# 11 	100
# 12 	100
# 13 	100
# 14 	100
# 15 	100
# 16 	100
# 17 	100
# 18 	100
# 19 	100
# 20 	100
# 21 	100
# 22 	100
# 23 	100
# 24 	100
# 25 	100
# 26 	100
# 27 	100
# 28 	100
# 29 	100
# 30 	100
# 2025-12-03 16:06:41.438867	遗传算法优化完成，耗时6秒
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 25, 'atr_ma_length': 30}, 目标：0
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 26, 'atr_ma_length': 30}, 目标：0
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 27, 'atr_ma_length': 20}, 目标：0
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 26, 'atr_ma_length': 10}, 目标：0
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 26, 'atr_ma_length': 20}, 目标：0
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 27, 'atr_ma_length': 30}, 目标：0
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 25, 'atr_ma_length': 10}, 目标：0
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 25, 'atr_ma_length': 20}, 目标：0
# 2025-12-03 16:06:41.550878	参数：{'atr_length': 27, 'atr_ma_length': 10}, 目标：0
# [({'atr_length': 25, 'atr_ma_length': 30}, 0, {}),
#  ({'atr_length': 26, 'atr_ma_length': 30}, 0, {}),
#  ({'atr_length': 27, 'atr_ma_length': 20}, 0, {}),
#  ({'atr_length': 26, 'atr_ma_length': 10}, 0, {}),
#  ({'atr_length': 26, 'atr_ma_length': 20}, 0, {}),
#  ({'atr_length': 27, 'atr_ma_length': 30}, 0, {}),
#  ({'atr_length': 25, 'atr_ma_length': 10}, 0, {}),
#  ({'atr_length': 25, 'atr_ma_length': 20}, 0, {}),
#  ({'atr_length': 27, 'atr_ma_length': 10}, 0, {})]

# %%
engine.run_bf_optimization(setting)
# Out:
# 2025-12-03 16:06:41.564880	开始执行穷举算法优化
# 2025-12-03 16:06:41.564880	参数优化空间：9
# 100%|██████████| 9/9 [00:01<00:00,  5.51it/s]
# 2025-12-03 16:06:43.594778	穷举算法优化完成，耗时2秒
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 25, 'atr_ma_length': 10}, 目标：0
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 25, 'atr_ma_length': 20}, 目标：0
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 25, 'atr_ma_length': 30}, 目标：0
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 26, 'atr_ma_length': 10}, 目标：0
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 26, 'atr_ma_length': 20}, 目标：0
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 26, 'atr_ma_length': 30}, 目标：0
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 27, 'atr_ma_length': 10}, 目标：0
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 27, 'atr_ma_length': 20}, 目标：0
# 2025-12-03 16:06:43.784861	参数：{'atr_length': 27, 'atr_ma_length': 30}, 目标：0
# [({'atr_length': 25, 'atr_ma_length': 10}, 0, {}),
#  ({'atr_length': 25, 'atr_ma_length': 20}, 0, {}),
#  ({'atr_length': 25, 'atr_ma_length': 30}, 0, {}),
#  ({'atr_length': 26, 'atr_ma_length': 10}, 0, {}),
#  ({'atr_length': 26, 'atr_ma_length': 20}, 0, {}),
#  ({'atr_length': 26, 'atr_ma_length': 30}, 0, {}),
#  ({'atr_length': 27, 'atr_ma_length': 10}, 0, {}),
#  ({'atr_length': 27, 'atr_ma_length': 20}, 0, {}),
#  ({'atr_length': 27, 'atr_ma_length': 30}, 0, {})]
